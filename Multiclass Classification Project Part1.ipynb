# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/HW5')

import mltools

# %% [markdown]
# # Data Exploration

# %%
import mltools as ml
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
# %matplotlib inline
import mltools as ml
import pandas as pd

#Loading data as csv file
df = pd.read_csv ('/data.csv', delimiter = ";")

#Allocating first 11 columns to X
X = df.iloc[:,:11]
#Allocationg last column to Y
Y = df.iloc[:,-1]


print(X)
print(Y)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print(np.unique(df.iloc[:,-1]))
#Finding class labels
# Out:
# [3 4 5 6 7 8 9]

# %%
print(df.columns)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
print(df.T)
# Out:
#                          0        1        2         3         4        5     \
# fixed acidity           7.000    6.300   8.1000    7.2000    7.2000   8.1000
# volatile acidity        0.270    0.300   0.2800    0.2300    0.2300   0.2800
# citric acid             0.360    0.340   0.4000    0.3200    0.3200   0.4000
# residual sugar         20.700    1.600   6.9000    8.5000    8.5000   6.9000
# chlorides               0.045    0.049   0.0500    0.0580    0.0580   0.0500
# free sulfur dioxide    45.000   14.000  30.0000   47.0000   47.0000  30.0000
# total sulfur dioxide  170.000  132.000  97.0000  186.0000  186.0000  97.0000
# density                 1.001    0.994   0.9951    0.9956    0.9956   0.9951
# pH                      3.000    3.300   3.2600    3.1900    3.1900   3.2600
# sulphates               0.450    0.490   0.4400    0.4000    0.4000   0.4400
# alcohol                 8.800    9.500  10.1000    9.9000    9.9000  10.1000
# ...

# %%
df.info()
#11 features 1 label 4898 rows and 12 columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
print(df.describe())
#Getting mean, std, min, percentiles and max value of each feature
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
data1 = df.iloc[:500,0:11]
data2 = df.iloc[500:1000,0:11]
data3 = df.iloc[1000:1500,0:11]
data4 = df.iloc[1500:2000,0:11]
data5 = df.iloc[2000:2500,0:11]
data6 = df.iloc[2500:3000,0:11]
data7 = df.iloc[3000:3500,0:11]
data8 = df.iloc[3500:4000,0:11]
data9 = df.iloc[4000:4500,0:11]
data10 = df.iloc[4500:,0:11]

# %%
data1.plot(kind='area')
data1.plot(kind='hist')
data1.plot(kind='box')

# %%
data2.plot(kind='area')
data2.plot(kind='hist')
data2.plot(kind='box')

# %%
data3.plot(kind='area')
data3.plot(kind='hist')
data3.plot(kind='box')

# %%
data4.plot(kind='area')
data4.plot(kind='hist')
data4.plot(kind='box')

# %%
data5.plot(kind='area')
data5.plot(kind='hist')
data5.plot(kind='box')

# %%
data6.plot(kind='area')
data6.plot(kind='hist')
data6.plot(kind='box')

# %%
data7.plot(kind='area')
data7.plot(kind='hist')
data7.plot(kind='box')

# %%
data8.plot(kind='area')
data8.plot(kind='hist')
data8.plot(kind='box')

# %%
data9.plot(kind='area')
data9.plot(kind='hist')
data9.plot(kind='box')

# %%
data10.plot(kind='area')
data10.plot(kind='hist')
data10.plot(kind='box')

# %%
data = df.to_numpy()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 4, figsize=(8, 8))
mask = data[:, -1] == 3 
axs[0,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[0,1].hist(data[mask, 1], bins=8, color = 'blue' )
axs[0,2].hist(data[mask, 2], bins=8, color = 'green')
axs[0,3].hist(data[mask, 3], bins=8, color = 'yellow' )
mask = data[:, -1] == 4
axs[1,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[1,1].hist(data[mask, 1], bins=8, color = 'blue' ) 
axs[1,2].hist(data[mask, 2], bins=8 , color = 'green') 
axs[1,3].hist(data[mask, 3], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 5 
axs[2,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[2,1].hist(data[mask, 1], bins=8, color = 'blue' ) 
axs[2,2].hist(data[mask, 2], bins=8 , color = 'green') 
axs[2,3].hist(data[mask, 3], bins=8, color = 'yellow' )
# Out:
# (array([497., 161., 300., 185., 154.,  94.,  62.,   4.]),
#  array([ 0.6   ,  3.4625,  6.325 ,  9.1875, 12.05  , 14.9125, 17.775 ,
#         20.6375, 23.5   ]),
#  <a list of 8 Patch objects>)

# %%
fig, axs = plt.subplots(4, 4, figsize=(8, 8))
mask = data[:, -1] == 6 
axs[0,0].hist(data[0:49, 0], bins=8, color = 'red' ) 
axs[0,1].hist(data[0:49, 1], bins=8, color = 'blue' )
axs[0,2].hist(data[0:49, 2], bins=8, color = 'green')
axs[0,3].hist(data[0:49, 3], bins=8, color = 'yellow' )
mask = data[:, -1] == 7 
axs[1,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[1,1].hist(data[mask, 1], bins=8, color = 'blue' ) 
axs[1,2].hist(data[mask, 2], bins=8 , color = 'green') 
axs[1,3].hist(data[mask, 3], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 8 
axs[2,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[2,1].hist(data[mask, 1], bins=8, color = 'blue' ) 
axs[2,2].hist(data[mask, 2], bins=8 , color = 'green') 
axs[2,3].hist(data[mask, 3], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 9 
axs[3,0].hist(data[mask, 0], bins=8, color = 'red' ) 
axs[3,1].hist(data[mask, 1], bins=8, color = 'blue' ) 
axs[3,2].hist(data[mask, 2], bins=8 , color = 'green') 
axs[3,3].hist(data[mask, 3], bins=8, color = 'yellow' )
# Out:
# (array([3., 0., 1., 0., 0., 0., 0., 1.]),
#  array([ 1.6  ,  2.725,  3.85 ,  4.975,  6.1  ,  7.225,  8.35 ,  9.475,
#         10.6  ]),
#  <a list of 8 Patch objects>)

# %%
fig, axs = plt.subplots(7, 4, figsize=(10, 10))
mask = data[:, -1] == 3 
axs[0,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[0,1].hist(data[mask, 5], bins=8, color = 'blue' )
axs[0,2].hist(data[mask, 6], bins=8, color = 'green')
axs[0,3].hist(data[mask, 7], bins=8, color = 'yellow' )
mask = data[:, -1] == 4
axs[1,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[1,1].hist(data[mask, 5], bins=8, color = 'blue' ) 
axs[1,2].hist(data[mask, 6], bins=8 , color = 'green') 
axs[1,3].hist(data[mask, 7], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 5 
axs[2,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[2,1].hist(data[mask, 5], bins=8, color = 'blue' ) 
axs[2,2].hist(data[mask, 6], bins=8 , color = 'green') 
axs[2,3].hist(data[mask, 7], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 6 
axs[3,0].hist(data[0:49, 4], bins=8, color = 'red' ) 
axs[3,1].hist(data[0:49, 5], bins=8, color = 'blue' )
axs[3,2].hist(data[0:49, 6], bins=8, color = 'green')
axs[3,3].hist(data[0:49, 7], bins=8, color = 'yellow' )
mask = data[:, -1] == 7 
axs[4,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[4,1].hist(data[mask, 5], bins=8, color = 'blue' ) 
axs[4,2].hist(data[mask, 6], bins=8 , color = 'green') 
axs[4,3].hist(data[mask, 7], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 8 
axs[5,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[5,1].hist(data[mask, 5], bins=8, color = 'blue' ) 
axs[5,2].hist(data[mask, 6], bins=8 , color = 'green') 
axs[5,3].hist(data[mask, 7], bins=8, color = 'yellow' ) 
mask = data[:, -1] == 9 
axs[6,0].hist(data[mask, 4], bins=8, color = 'red' ) 
axs[6,1].hist(data[mask, 5], bins=8, color = 'blue' ) 
axs[6,2].hist(data[mask, 6], bins=8 , color = 'green') 
axs[6,3].hist(data[mask, 7], bins=8, color = 'yellow' )
# Out:
# (array([4., 0., 0., 0., 0., 0., 0., 1.]),
#  array([0.98965   , 0.99056875, 0.9914875 , 0.99240625, 0.993325  ,
#         0.99424375, 0.9951625 , 0.99608125, 0.997     ]),
#  <a list of 8 Patch objects>)

# %%
fig, axs = plt.subplots(7, 3, figsize=(10, 10))
mask = data[:, -1] == 3 
axs[0,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[0,1].hist(data[mask, 9], bins=8, color = 'blue' )
axs[0,2].hist(data[mask, 10], bins=8, color = 'green')

mask = data[:, -1] == 4
axs[1,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[1,1].hist(data[mask, 9], bins=8, color = 'blue' ) 
axs[1,2].hist(data[mask, 10], bins=8 , color = 'green') 

mask = data[:, -1] == 5 
axs[2,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[2,1].hist(data[mask, 9], bins=8, color = 'blue' ) 
axs[2,2].hist(data[mask, 10], bins=8 , color = 'green') 

mask = data[:, -1] == 6 
axs[3,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[3,1].hist(data[mask, 9], bins=8, color = 'blue' )
axs[3,2].hist(data[mask, 10], bins=8, color = 'green')

mask = data[:, -1] == 7 
axs[4,0].hist(data[mask, 8], bins=13, color = 'red' ) 
axs[4,1].hist(data[mask, 9], bins=13, color = 'blue' ) 
axs[4,2].hist(data[mask, 10], bins=13 , color = 'green') 

mask = data[:, -1] == 8 
axs[5,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[5,1].hist(data[mask, 9], bins=8, color = 'blue' ) 
axs[5,2].hist(data[mask, 10], bins=8, color = 'green') 

mask = data[:, -1] == 9 
axs[6,0].hist(data[mask, 8], bins=8, color = 'red' ) 
axs[6,1].hist(data[mask, 9], bins=8, color = 'blue' ) 
axs[6,2].hist(data[mask, 10], bins=8 , color = 'green')
# Out:
# (array([1., 0., 0., 0., 0., 0., 2., 2.]),
#  array([10.4   , 10.7125, 11.025 , 11.3375, 11.65  , 11.9625, 12.275 ,
#         12.5875, 12.9   ]),
#  <a list of 8 Patch objects>)

# %%
print(np.unique(data[:,-1]))
data1 = data[:500,:]
data2 = data[500:1000,:]
data3 = data[1000:1500,:]
data4 = data[1500:2000,:]
data5 = data[2000:2500,:]
data6 = data[2500:3000,:]
data7 = data[3000:3500,:]
data8 = data[3500:4000,:]
data9 = data[4000:4500,:]
data10 = data[4500:,:]
# Out:
# [3. 4. 5. 6. 7. 8. 9.]

# %%
fig, axs = plt.subplots(5, 2, figsize=(10, 10))

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta']  #Taking an array of colors
for i, c in enumerate(np.unique(data1[:, -1])):
    mask = data1[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,0].scatter(data1[mask, 0], data1[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data2[:, -1])):
    mask = data2[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,1].scatter(data2[mask, 0], data2[mask, 1], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data3[:, -1])):
    mask = data3[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,0].scatter(data3[mask, 0], data3[mask, 1], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data4[:, -1])):
    mask = data4[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,1].scatter(data4[mask, 0], data4[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data5[:, -1])):
    mask = data5[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,0].scatter(data5[mask, 0], data5[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data6[:, -1])):
    mask = data6[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,1].scatter(data6[mask, 0], data6[mask, 1], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data7[:, -1])):
    mask = data7[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,0].scatter(data7[mask, 0], data7[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data8[:, -1])):
    mask = data8[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,1].scatter(data8[mask, 0], data8[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data9[:, -1])):
    mask = data9[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,0].scatter(data9[mask, 0], data9[mask, 1], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data10[:, -1])):
    mask = data10[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,1].scatter(data10[mask, 0], data10[mask, 1], s=10, color=colors[i], alpha=0.75)

# %%
fig, axs = plt.subplots(5, 2, figsize=(10, 10))

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta']  #Taking an array of colors
for i, c in enumerate(np.unique(data1[:, -1])):
    mask = data1[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,0].scatter(data1[mask, 1], data1[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data2[:, -1])):
    mask = data2[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,1].scatter(data2[mask, 1], data2[mask, 2], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data3[:, -1])):
    mask = data3[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,0].scatter(data3[mask, 1], data3[mask, 2], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data4[:, -1])):
    mask = data4[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,1].scatter(data4[mask, 1], data4[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data5[:, -1])):
    mask = data5[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,0].scatter(data5[mask, 1], data5[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data6[:, -1])):
    mask = data6[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,1].scatter(data6[mask, 1], data6[mask, 2], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data7[:, -1])):
    mask = data7[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,0].scatter(data7[mask, 1], data7[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data8[:, -1])):
    mask = data8[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,1].scatter(data8[mask, 1], data8[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data9[:, -1])):
    mask = data9[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,0].scatter(data9[mask, 1], data9[mask, 2], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data10[:, -1])):
    mask = data10[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,1].scatter(data10[mask, 1], data10[mask, 2], s=10, color=colors[i], alpha=0.75)

# %%
fig, axs = plt.subplots(5, 2, figsize=(10, 10))

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta']  #Taking an array of colors
for i, c in enumerate(np.unique(data1[:, -1])):
    mask = data1[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,0].scatter(data1[mask, 2], data1[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data2[:, -1])):
    mask = data2[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[0,1].scatter(data2[mask, 2], data2[mask, 3], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data3[:, -1])):
    mask = data3[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,0].scatter(data3[mask, 2], data3[mask, 3], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data4[:, -1])):
    mask = data4[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[1,1].scatter(data4[mask, 2], data4[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data5[:, -1])):
    mask = data5[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,0].scatter(data5[mask, 2], data5[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data6[:, -1])):
    mask = data6[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[2,1].scatter(data6[mask, 2], data6[mask, 3], s=10, color=colors[i], alpha=0.75)


colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data7[:, -1])):
    mask = data7[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,0].scatter(data7[mask, 2], data7[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data8[:, -1])):
    mask = data8[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[3,1].scatter(data8[mask, 2], data8[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data9[:, -1])):
    mask = data9[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,0].scatter(data9[mask, 2], data9[mask, 3], s=10, color=colors[i], alpha=0.75)

colors = ['blue', 'green', 'red', 'orange', 'yellow', 'pink', 'violet', 'magenta'] #Taking an array of colors
for i, c in enumerate(np.unique(data10[:, -1])):
    mask = data10[:, -1] == c # Finding the right points
#scatter plot between feature 1 and feature2 for all sets of data
    axs[4,1].scatter(data10[mask, 2], data10[mask, 3], s=10, color=colors[i], alpha=0.75)

# %% [markdown]
# # Model Exploration

# %%
print(data.shape)
X = data[:,0:11]
Y= data[:,-1]
print(X)
print(Y)
X,Y = ml.shuffleData(X,Y)  
Xtr, Xva, Ytr, Yva = ml.splitData(X, Y)
Xt, Yt = Xtr[:2000], Ytr[:2000] # subsample for efficiency (you can go higher)
XtS, params = ml.rescale(Xt) # Normalize the features
XvS,_ = ml.rescale(Xva, params) # Normalize the features
# Out:
# (4898, 12)
# [[ 7.    0.27  0.36 ...  3.    0.45  8.8 ]
#  [ 6.3   0.3   0.34 ...  3.3   0.49  9.5 ]
#  [ 8.1   0.28  0.4  ...  3.26  0.44 10.1 ]
#  ...
#  [ 6.5   0.24  0.19 ...  2.99  0.46  9.4 ]
#  [ 5.5   0.29  0.3  ...  3.34  0.38 12.8 ]
#  [ 6.    0.21  0.38 ...  3.26  0.32 11.8 ]]
# [6. 6. 6. ... 6. 7. 6.]

# %% [markdown]
# K nearest neighbour

# %%
K = [1, 10, 20, 50, 100]
A = [1,2,3,4,5] #A = range(1,6)
tr_error = np.zeros((len(K),len(A)))
va_error = np.zeros((len(K),len(A)))
for i,k in enumerate(K):
    for j,a in enumerate(A):
# train learner using k and a
        learner = ml.knn.knnClassify()
        learner.train(XtS, Yt, K=k, alpha=a)
        tr_error[i][j] = learner.err(XtS, Yt)
        va_error[i][j] = learner.err(XvS, Yva)
# Now plot it
print(tr_error)
print(va_error)
f, ax = plt.subplots(1, 1, figsize=(8, 5))
cax = ax.matshow(tr_error, interpolation = 'nearest')
#cax = ax.matshow(va_auc, interpolation = 'nearest')
f.colorbar(cax)
ax.set_xticklabels(['regularization']+A)
ax.set_yticklabels(['KNN Values']+K)
plt.show()
# Out:
# /content/drive/MyDrive/HW5/mltools/knn.py:103: RuntimeWarning: invalid value encountered in true_divide
#   prob[i,:] = count / count.sum()    # save (soft) results
# [[0.     0.     0.     0.     0.    ]
#  [0.0595 0.0055 0.002  0.001  0.001 ]
#  [0.077  0.006  0.002  0.001  0.001 ]
#  [0.0935 0.007  0.002  0.001  0.001 ]
#  [0.102  0.0065 0.002  0.001  0.001 ]]
# [[0.44489796 0.44489796 0.44591837 0.44591837 0.44591837]
#  [0.41530612 0.42755102 0.42959184 0.42755102 0.42959184]
#  [0.40816327 0.42244898 0.42755102 0.42653061 0.42857143]
#  [0.40408163 0.4255102  0.42653061 0.42653061 0.42857143]
#  [0.40918367 0.4244898  0.42653061 0.42653061 0.42857143]]

# %%
f, ax = plt.subplots(1, 1, figsize=(8, 5))
#cax = ax.matshow(tr_error, interpolation = 'nearest')
cax = ax.matshow(va_error, interpolation = 'nearest')
f.colorbar(cax)
ax.set_xticklabels(['regularization']+A)
ax.set_yticklabels(['KNN Values']+K)
plt.show()

# %% [markdown]
# Decision trees

# %%
maxdepth=[2,5,10,15,30,50,100]
ErrorT=[]
ErrorV=[]

for i in maxdepth:
    learner = ml.dtree.treeClassify(Xtr, Ytr, maxDepth=i, minParent=15, minLeaf=15)
    learner.err(Xtr, Ytr) # train AUC
    ErrorT.append(learner.err(Xtr, Ytr))
    ErrorV.append(learner.err(Xva, Yva))

print(ErrorT)
print(ErrorV)
    
plt.plot(maxdepth, ErrorT, 'r-', lw=3, label="Training Error")
plt.plot(maxdepth, ErrorV, 'b-', lw=3, label="Validation Error")
plt.title("Training and validation Error")
plt.legend()
# Out:
# [0.4892802450229709, 0.4550791220010209, 0.35273098519652885, 0.33588565594691167, 0.33588565594691167, 0.33588565594691167, 0.33588565594691167]
# [0.48367346938775513, 0.46530612244897956, 0.4673469387755102, 0.4846938775510204, 0.4857142857142857, 0.4857142857142857, 0.4846938775510204]

# %% [markdown]
# # Random Forest

# %%
tree_one = ml.dtree.treeClassify(Xtr, Ytr, minParent=45, maxDepth=25, nFeatures=6) # The nFeatures makes it random
print(tree_one.err(Xtr, Ytr))
print(tree_one.err(Xva, Yva))
# Out:
# 0.34711587544665645
# 0.4744897959183674

# %%
np.random.seed(0) # Resetting the seed in case you ran other stuff.
n_bags = 10
bags = [] # self.learners
for l in range(n_bags):
# Each boosted data is the size of the original data.
    Xi, Yi = ml.bootstrapData(Xtr, Ytr, Xtr.shape[0]) 
# Train the model on that draw
    tree = ml.dtree.treeClassify(Xi, Yi, minParent=45, maxDepth=25, nFeatures=6)
    bags.append(tree)

# %%
Train_Error = []
Validation_Error = []
num = list(range(10))
for l in range(n_bags):
    print("Decision Tree : {0}".format(l))
    print('Train Error', bags[l].err(Xtr, Ytr))
    print('Validation Error', bags[l].err(Xva, Yva))
    Train_Error.append(bags[l].err(Xtr, Ytr))
    Validation_Error.append(bags[l].err(Xva, Yva))


print(Train_Error)
print(Validation_Error)
Error = np.mean(Validation_Error)
print(Error)
# Out:
# Decision Tree : 0
# Train Error 0.38718734047983666
# Validation Error 0.4785714285714286
# Decision Tree : 1
# Train Error 0.39152628892291985
# Validation Error 0.46530612244897956
# Decision Tree : 2
# Train Error 0.3981623277182236
# Validation Error 0.4775510204081633
# Decision Tree : 3
# Train Error 0.38131699846860645
# Validation Error 0.49387755102040815
# Decision Tree : 4
# Train Error 0.3876978050025523
# Validation Error 0.49795918367346936
# Decision Tree : 5
# Train Error 0.3948443083205717
# Validation Error 0.4989795918367347
# Decision Tree : 6
# Train Error 0.3961204696273609
# Validation Error 0.5153061224489796
# Decision Tree : 7
# Train Error 0.39280245022970905
# Validation Error 0.47959183673469385
# Decision Tree : 8
# Train Error 0.3731495661051557
# Validation Error 0.47653061224489796
# Decision Tree : 9
# Train Error 0.38157223072996427
# Validation Error 0.503061224489796
# ...

# %%
class BaggedTree(ml.base.classifier):
    def __init__(self, learners):

        self.learners = learners
    def predictSoft(self, X):

        n_bags = len(self.learners)
        preds = [self.learners[l].predictSoft(X) for l in range(n_bags)]
        return np.mean(preds, axis=0)

bt = BaggedTree(bags)
bt.classes = np.unique(Y)
print("{0:>15}: {1:.4f}".format('Train Error', bt.err(Xtr, Ytr)))
print("{0:>15}: {1:.4f}".format('Validation Error', bt.err(Xva, Yva)))
# Out:
#     Train Error: 0.2690
# Validation Error: 0.3980

# %% [markdown]
# # Neural Network

# %%
layers = [1, 2, 4, 6]
nodes = [5, 10, 25, 50, 100]
input = [11]
output = [7]

tr_err = np.zeros((len(layers),len(nodes)))
va_err= np.zeros((len(layers),len(nodes)))


for n,k in enumerate(layers):
    for i, j in enumerate(nodes):
        
        size = input+k*[j]+output
        print(size)

        nn = ml.nnet.nnetClassify()
        nn.init_weights(size, 'random',XtS, Yt) # as many layers nodes you want

        nn.train(XtS, Yt, stopTol=1e-8, stepsize=.25, stopIter=300)
        tr_err[n][i] = nn.err(XtS, Yt)
        va_err[n][i] = nn.err(XvS, Yva)

print(tr_err)
print(va_err)

f, ax = plt.subplots(1, 1, figsize=(8, 5))
cax = ax.matshow(tr_err, interpolation='nearest')
f.colorbar(cax)
ax.set_xticklabels(['']+nodes)
ax.set_yticklabels(['']+layers)
plt.show()

f, ax = plt.subplots(1, 1, figsize=(8, 5))
cax = ax.matshow(va_err, interpolation='nearest')
f.colorbar(cax)
ax.set_xticklabels(['']+nodes)
ax.set_yticklabels(['']+layers)
plt.show()
# Out:
# [11, 5, 7]
# it 1 : Jsur = 0.6060628803544678, J01 = 0.4845
# it 2 : Jsur = 0.6018919647201209, J01 = 0.4865
# it 4 : Jsur = 0.5983525534075166, J01 = 0.4795
# it 8 : Jsur = 0.5924335260073957, J01 = 0.472
# it 16 : Jsur = 0.5869450778875822, J01 = 0.4595
# it 32 : Jsur = 0.5838509947315977, J01 = 0.458
# it 64 : Jsur = 0.5824378247770918, J01 = 0.4455
# it 128 : Jsur = 0.5819648633040078, J01 = 0.4455
# [11, 10, 7]
# it 1 : Jsur = 0.6068671428149044, J01 = 0.475
# it 2 : Jsur = 0.6010480363154952, J01 = 0.4715
# it 4 : Jsur = 0.5945999546417697, J01 = 0.456
# it 8 : Jsur = 0.587434486697028, J01 = 0.448
# it 16 : Jsur = 0.5823612399482075, J01 = 0.438
# it 32 : Jsur = 0.5791961068031914, J01 = 0.435
# it 64 : Jsur = 0.5766649029749525, J01 = 0.442
# it 128 : Jsur = 0.5743838542440021, J01 = 0.436
# it 256 : Jsur = 0.5717128341635059, J01 = 0.4355
# [11, 25, 7]
# it 1 : Jsur = 0.6133390758031438, J01 = 0.477
# it 2 : Jsur = 0.6023702920268534, J01 = 0.4695
# ...

# %%
layers = [1, 2, 4, 6]
nodes = [5, 10, 25, 50, 100]
input = [11]
output = [7]

tr_err = np.zeros((len(layers),len(nodes)))
va_err= np.zeros((len(layers),len(nodes)))


for n,k in enumerate(layers):
    for i, j in enumerate(nodes):
        
        size = input+k*[j]+output
        print(size)

        nn = ml.nnet.nnetClassify()
        nn.setActivation('logistic')
        nn.init_weights(size, 'random',XtS, Yt) # as many layers nodes you want

        nn.train(XtS, Yt, stopTol=1e-8, stepsize=.25, stopIter=300)
        tr_err[n][i] = nn.err(XtS, Yt)
        va_err[n][i] = nn.err(XvS, Yva)

print(tr_err)
print(va_err)

f, ax = plt.subplots(1, 1, figsize=(8, 5))
cax = ax.matshow(tr_err, interpolation='nearest')
f.colorbar(cax)
ax.set_xticklabels(['']+nodes)
ax.set_yticklabels(['']+layers)
plt.show()

f, ax = plt.subplots(1, 1, figsize=(8, 5))
cax = ax.matshow(va_err, interpolation='nearest')
f.colorbar(cax)
ax.set_xticklabels(['']+nodes)
ax.set_yticklabels(['']+layers)
plt.show()
# Out:
# [11, 5, 7]
# it 1 : Jsur = 0.6175536564778857, J01 = 0.4795
# it 2 : Jsur = 0.5994043488964812, J01 = 0.4675
# it 4 : Jsur = 0.5927198365656422, J01 = 0.463
# it 8 : Jsur = 0.5902240944751629, J01 = 0.459
# it 16 : Jsur = 0.5890144131376173, J01 = 0.4585
# it 32 : Jsur = 0.5883026547402603, J01 = 0.4615
# it 64 : Jsur = 0.5879183023439921, J01 = 0.4615
# it 128 : Jsur = 0.5877179146402213, J01 = 0.4595
# [11, 10, 7]
# it 1 : Jsur = 0.6206657678262308, J01 = 0.4765
# it 2 : Jsur = 0.6014715375418502, J01 = 0.4675
# it 4 : Jsur = 0.5954098319076961, J01 = 0.464
# it 8 : Jsur = 0.5934257365374166, J01 = 0.456
# it 16 : Jsur = 0.5929293479752328, J01 = 0.458
# it 32 : Jsur = 0.5927226717048764, J01 = 0.459
# it 64 : Jsur = 0.5925496552842546, J01 = 0.454
# it 128 : Jsur = 0.5923629365662775, J01 = 0.452
# it 256 : Jsur = 0.5920403511693041, J01 = 0.449
# [11, 25, 7]
# it 1 : Jsur = 0.6337591872153646, J01 = 0.487
# it 2 : Jsur = 0.6048023538695697, J01 = 0.4635
# ...

# %% [markdown]
# # Validation/Cross Validation

# %%
np.random.seed(0) # Resetting the seed in case you ran other stuff.
n_bags = 10
bags = [] # self.learners
for l in range(n_bags):
# Each boosted data is the size of the original data.
    Xi, Yi = ml.bootstrapData(Xtr, Ytr, Xtr.shape[0]) 
# Train the model on that draw
    tree = ml.dtree.treeClassify(Xi, Yi, minParent=12,maxDepth=25, nFeatures=6)
    bags.append(tree)
Train_Error = []
Validation_Error = []
num = list(range(10))
for l in range(n_bags):
    print("Decision Tree : {0}".format(l))
    print('Train Error', bags[l].err(Xtr, Ytr))
    print('Validation Error', bags[l].err(Xva, Yva))
    Train_Error.append(bags[l].err(Xtr, Ytr))
    Validation_Error.append(bags[l].err(Xva, Yva))


print(Train_Error)
print(Validation_Error)
min_value = min(Train_Error)
min_index = Train_Error.index(min_value)
print("The minimum train error is ",min_value, "having the index of", min_index )
min_value = min(Validation_Error)
min_index = Validation_Error.index(min_value)
print("The minimum validation error is ",min_value, "having the index of", min_index )

# %%
class BaggedTree(ml.base.classifier):
    def __init__(self, learners):

        self.learners = learners
    def predictSoft(self, X):

        n_bags = len(self.learners)
        preds = [self.learners[l].predictSoft(X) for l in range(n_bags)]
        return np.mean(preds, axis=0)

bt = BaggedTree(bags)
bt.classes = np.unique(Y)
print("{0:>15}: {1:.4f}".format('Train Error', bt.err(Xtr, Ytr)))
print("{0:>15}: {1:.4f}".format('Validation Error', bt.err(Xva, Yva)))
